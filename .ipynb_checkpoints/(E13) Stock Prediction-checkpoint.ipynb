# %% [markdown]
# # (E13) 프로젝트 : 주식 예측에 도전해 보자

# %% [markdown]
# - ARIMA를 통해 시계열 데이터를 예측하는 프로젝트입니다.
# - 시계열 데이터 중에 안정적(Stationary) 데이터에 대해서만 미래 예측이 가능하기 때문에 안정적인 데이터인지 확인합니다.

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from matplotlib.pylab import rcParams
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# ## Data Load

# %% [markdown]
# - 칼럼 종류: Date, Open, High, Low, Close, Adj Close, Volume
# - 날짜별로 시작가(Open), 최고가(High), 최저가(Low), 종가(Close), 수정종가(Adj Close), 거래량(Volume)이 저장되어 있는 것을 확인할 수 있지만, 우리는 Close만 사용하겠습니다. (주식 시장은 정해진 시간 동안만 거래가 가능합니다. 종가란 하루의 장이 마감하였을 때의 가격입니다.)

# %%
# Data Load
dataset_filepath = os.getenv('HOME')+'/aiffel/stock_prediction/data/005930.KS.csv' 
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

# Time Series 생성
rcParams['figure.figsize'] = 13, 6
plt.plot(ts)

ts.head()
# Out:
# Date
# 2000-01-04    6110.0
# 2000-01-05    5580.0
# 2000-01-06    5620.0
# 2000-01-07    5540.0
# 2000-01-10    5770.0
# Name: Close, dtype: float64

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# - 결측치 처리
# - 로그 변환

# %%
# 결측치 처리
ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Date
# 2005-01-03   NaN
# 2017-11-16   NaN
# 2017-11-23   NaN
# 2018-01-02   NaN
# 2018-11-15   NaN
# 2019-11-14   NaN
# Name: Close, dtype: float64

# %%
# 결측치가 있다면 이를 보간합니다. 보간 기준은 time을 선택합니다. 
ts=ts.interpolate(method='time')

# 보간 이후 결측치(NaN) 유무를 다시 확인합니다.
print(ts[ts.isna()])

plt.plot(ts)
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환
ts_log = np.log(ts)
plt.plot(ts_log)

# %% [markdown]
# ## Rolling Statistics 시각화

# %%
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  # 이동평균 시계열
    rolstd = timeseries.rolling(window=window).std()    # 이동표준편차 시계열

     # 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화해 본다.
    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

# %% [markdown]
# ## Augmented Dickey-Fuller Test

# %%
def augmented_dickey_fuller_test(timeseries):
    # statsmodels 패키지에서 제공하는 adfuller 메소드를 호출합니다.
    dftest = adfuller(timeseries, autolag='AIC')  
    
    # adfuller 메소드가 리턴한 결과를 정리하여 출력합니다.
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %% [markdown]
# ## 시계열 안정성 분석

# %% [markdown]
# - 정성적 그래프 분석
# - 정량적 Augmented Dicky-Fuller Test
# - 시계열 분해(Time Series Decomposition)
# - Residual 안정성 확인

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.rcParams["figure.figsize"] = (11,6)
plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -0.323791
# p-value                           0.922067
# #Lags Used                        4.000000
# Number of Observations Used    5316.000000
# Critical Value (1%)              -3.431581
# Critical Value (5%)              -2.862084
# Critical Value (10%)             -2.567059
# dtype: float64

# %%
# Residual 안정성 확인
plt.rcParams["figure.figsize"] = (13,6)
plot_rolling_statistics(residual)

# %%
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.760785e+01
# p-value                        3.892724e-30
# #Lags Used                     3.300000e+01
# Number of Observations Used    5.257000e+03
# Critical Value (1%)           -3.431595e+00
# Critical Value (5%)           -2.862090e+00
# Critical Value (10%)          -2.567063e+00
# dtype: float64

# %% [markdown]
# ## 학습, 테스트 데이터셋 생성

# %%
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
print(ts_log[:2])
print(train_data.shape)
print(test_data.shape)
# Out:
# Date
# 2000-01-04    8.717682
# 2000-01-05    8.626944
# Name: Close, dtype: float64
# (4788,)
# (533,)

# %% [markdown]
# ## 적정 ARIMA 모수 찾기

# %% [markdown]
# - ACF, PACF 그려보기 -> p,q 구하기
# - 차분 안정성 확인 -> d 구하기

# %%
# ACF, PACF 그려보기 -> p,q 구하기
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# %%
# 차분 안정성 확인 -> d 구하기
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -40.116434
# p-value                           0.000000
# #Lags Used                        3.000000
# Number of Observations Used    5316.000000
# Critical Value (1%)              -3.431581
# Critical Value (5%)              -2.862084
# Critical Value (10%)             -2.567059
# dtype: float64

# %%
# 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -21.847998
# p-value                           0.000000
# #Lags Used                       33.000000
# Number of Observations Used    5285.000000
# Critical Value (1%)              -3.431588
# Critical Value (5%)              -2.862087
# Critical Value (10%)             -2.567061
# dtype: float64

# %% [markdown]
# ## ARIMA 모델 훈련과 테스트

# %% [markdown]
# - ARIMA 모델 빌드와 훈련
# - 모델 테스트 및 플로팅
# - 최종 예측 모델 정확도 측정(MAPE)

# %%
from statsmodels.tsa.arima_model import ARIMA

# Build and Train  Model
model = ARIMA(train_data, order=(1, 1, 0))  
fitted_m = model.fit(disp=-1)  
print(fitted_m.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Close   No. Observations:                 4787
# Model:                 ARIMA(1, 1, 0)   Log Likelihood               11282.237
# Method:                       css-mle   S.D. of innovations              0.023
# Date:                Fri, 05 Mar 2021   AIC                         -22558.473
# Time:                        01:55:11   BIC                         -22539.052
# Sample:                             1   HQIC                        -22551.651
#
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0004      0.000      1.093      0.275      -0.000       0.001
# ar.L1.D.Close     0.0436      0.014      3.017      0.003       0.015       0.072
#                                     Roots
# ...
#                   Real          Imaginary           Modulus         Frequency
# ...

# %%
fitted_m.plot_predict()

# %%
# Forecast : 결과가 fc에 담깁니다. 
fc, se, conf = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과
lower_series = pd.Series(conf[:, 0], index=test_data.index)  # 예측결과의 하한 바운드
upper_series = pd.Series(conf[:, 1], index=test_data.index)  # 예측결과의 상한 바운드

# Plot
plt.figure(figsize=(9,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.10)
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  257635603.80197006
# MAE:  12871.759288620011
# RMSE:  16051.031237960073
# MAPE: 21.50%

# %% [markdown]
# - Mape 값의 결과가 21.50%로 높게 나왔습니다. 초기의 주가 그래프를 봤을때 전체적으로 주가가 상승하지만 2000-2002년도에는 하강한 상태에서 유지되는 모습을 보입니다. 따라서 2000-2002년도의 데이터를 제외한 2004년도부터 현재까지의 데이터를 사용해보겠습니다.

# %% [markdown]
# ## Samsung(2004~)

# %%
# Data Load
dataset_filepath = os.getenv('HOME')+'/aiffel/stock_prediction/data/005930.KS_2004.csv' 
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

# Time Series 생성
rcParams['figure.figsize'] = 13, 6
plt.plot(ts)

ts.head()
# Out:
# Date
# 2004-01-01    9020.0
# 2004-01-02    8980.0
# 2004-01-05    9150.0
# 2004-01-06    9200.0
# 2004-01-07    9300.0
# Name: Close, dtype: float64

# %%
# 결측치 처리
ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Date
# 2005-01-03   NaN
# 2017-11-16   NaN
# 2017-11-23   NaN
# 2018-01-02   NaN
# 2018-11-15   NaN
# 2019-11-14   NaN
# Name: Close, dtype: float64

# %%
# 결측치가 있다면 이를 보간합니다. 보간 기준은 time을 선택합니다. 
ts=ts.interpolate(method='time')

# 보간 이후 결측치(NaN) 유무를 다시 확인합니다.
print(ts[ts.isna()])

plt.plot(ts)
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환
ts_log = np.log(ts)
plt.plot(ts_log)

# %%
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  # 이동평균 시계열
    rolstd = timeseries.rolling(window=window).std()    # 이동표준편차 시계열

     # 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화해 본다.
    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

# %%
def augmented_dickey_fuller_test(timeseries):
    # statsmodels 패키지에서 제공하는 adfuller 메소드를 호출합니다.
    dftest = adfuller(timeseries, autolag='AIC')  
    
    # adfuller 메소드가 리턴한 결과를 정리하여 출력합니다.
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.rcParams["figure.figsize"] = (11,6)
plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -0.080298
# p-value                           0.951366
# #Lags Used                        4.000000
# Number of Observations Used    4274.000000
# Critical Value (1%)              -3.431881
# Critical Value (5%)              -2.862216
# Critical Value (10%)             -2.567130
# dtype: float64

# %%
# Residual 안정성 확인
plt.rcParams["figure.figsize"] = (13,6)
plot_rolling_statistics(residual)

# %%
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.666312e+01
# p-value                        1.567923e-29
# #Lags Used                     3.000000e+01
# Number of Observations Used    4.218000e+03
# Critical Value (1%)           -3.431901e+00
# Critical Value (5%)           -2.862225e+00
# Critical Value (10%)          -2.567135e+00
# dtype: float64

# %%
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
print(ts_log[:2])
print(train_data.shape)
print(test_data.shape)
# Out:
# Date
# 2004-01-01    9.107200
# 2004-01-02    9.102755
# Name: Close, dtype: float64
# (3851,)
# (428,)

# %%
# ACF, PACF 그려보기 -> p,q 구하기
plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# %%
# 차분 안정성 확인 -> d 구하기
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -36.305995
# p-value                           0.000000
# #Lags Used                        3.000000
# Number of Observations Used    4274.000000
# Critical Value (1%)              -3.431881
# Critical Value (5%)              -2.862216
# Critical Value (10%)             -2.567130
# dtype: float64

# %%
# 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -19.912164
# p-value                           0.000000
# #Lags Used                       31.000000
# Number of Observations Used    4245.000000
# Critical Value (1%)              -3.431891
# Critical Value (5%)              -2.862221
# Critical Value (10%)             -2.567133
# dtype: float64

# %%
# Build and Train  Model
model = ARIMA(train_data, order=(1, 1, 0))  
fitted_m = model.fit(disp=-1)  
print(fitted_m.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Close   No. Observations:                 3850
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                9866.876
# Method:                       css-mle   S.D. of innovations              0.019
# Date:                Fri, 05 Mar 2021   AIC                         -19727.752
# Time:                        01:55:14   BIC                         -19708.984
# Sample:                             1   HQIC                        -19721.086
#
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0004      0.000      1.322      0.186      -0.000       0.001
# ar.L1.D.Close     0.0459      0.016      2.849      0.004       0.014       0.077
#                                     Roots
# ...
#                   Real          Imaginary           Modulus         Frequency
# ...

# %%
fitted_m.plot_predict()

# %%
# Forecast : 결과가 fc에 담깁니다. 
fc, se, conf = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과
lower_series = pd.Series(conf[:, 0], index=test_data.index)  # 예측결과의 하한 바운드
upper_series = pd.Series(conf[:, 1], index=test_data.index)  # 예측결과의 상한 바운드

# Plot
plt.figure(figsize=(9,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.10)
plt.legend()
plt.show()

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  153676890.9384657
# MAE:  8325.64233326373
# RMSE:  12396.648375204715
# MAPE: 12.51%

# %% [markdown]
# - Mape의 값이 12.51%로 전체 데이터를 사용한 21.50%보다 감소하였습니다.

# %% [markdown]
# ## 다른 주식 종목 예측

# %% [markdown]
# ## Johnson & Johnson (JNJ)

# %%
# Data Load
dataset_jnj_filepath = os.getenv('HOME')+'/aiffel/stock_prediction/data/JNJ.csv' 
df_jnj = pd.read_csv(dataset_jnj_filepath, index_col='Date', parse_dates=True)
ts_jnj = df_jnj['Close']

# Time Series 생성
rcParams['figure.figsize'] = 13, 6
plt.plot(ts_jnj)

ts_jnj.head()
# Out:
# Date
# 2000-01-03    46.09375
# 2000-01-04    44.40625
# 2000-01-05    44.87500
# 2000-01-06    46.28125
# 2000-01-07    48.25000
# Name: Close, dtype: float64

# %%
# 결측치 처리
ts_jnj[ts_jnj.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 결측치가 있다면 이를 보간합니다. 보간 기준은 time을 선택합니다. 
ts_jnj=ts_jnj.interpolate(method='time')

# 보간 이후 결측치(NaN) 유무를 다시 확인합니다.
print(ts_jnj[ts_jnj.isna()])

plt.plot(ts_jnj)
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환
ts_jnj_log = np.log(ts_jnj)
plt.plot(ts_jnj_log)

# %%
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  
    rolstd = timeseries.rolling(window=window).std()

    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

# %%
def augmented_dickey_fuller_test(timeseries):
    dftest = adfuller(timeseries, autolag='AIC')  
    
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_jnj_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_jnj_log)

#시계열 분해 (Time Series Decomposition)
decomposition_jnj = seasonal_decompose(ts_jnj_log, model='multiplicative', period = 30) 

trend_jnj = decomposition_jnj.trend
seasonal_jnj = decomposition_jnj.seasonal
residual_jnj = decomposition_jnj.resid

plt.rcParams["figure.figsize"] = (11,6)
plt.subplot(411)
plt.plot(ts_jnj_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend_jnj, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal_jnj,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual_jnj, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -0.719206
# p-value                           0.841712
# #Lags Used                       17.000000
# Number of Observations Used    5307.000000
# Critical Value (1%)              -3.431583
# Critical Value (5%)              -2.862085
# Critical Value (10%)             -2.567060
# dtype: float64

# %%
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.666312e+01
# p-value                        1.567923e-29
# #Lags Used                     3.000000e+01
# Number of Observations Used    4.218000e+03
# Critical Value (1%)           -3.431901e+00
# Critical Value (5%)           -2.862225e+00
# Critical Value (10%)          -2.567135e+00
# dtype: float64

# %%
train_data, test_data = ts_jnj_log[:int(len(ts_jnj_log)*0.9)], ts_jnj_log[int(len(ts_jnj_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_jnj_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_jnj_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
print(ts_jnj_log[:2])
print(train_data.shape)
print(test_data.shape)
# Out:
# Date
# 2000-01-03    3.830677
# 2000-01-04    3.793380
# Name: Close, dtype: float64
# (4792,)
# (533,)

# %%
# ACF, PACF 그려보기 -> p,q 구하기
plot_acf(ts_jnj_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_jnj_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# %%
# 차분 안정성 확인 -> d 구하기
# 1차 차분 구하기
diff_1 = ts_jnj_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -19.483100
# p-value                           0.000000
# #Lags Used                       16.000000
# Number of Observations Used    5307.000000
# Critical Value (1%)              -3.431583
# Critical Value (5%)              -2.862085
# Critical Value (10%)             -2.567060
# dtype: float64

# %%
# Build and Train  Model
model = ARIMA(train_data, order=(1, 1, 0))  
fitted_m = model.fit(disp=-1)  
print(fitted_m.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Close   No. Observations:                 4791
# Model:                 ARIMA(1, 1, 0)   Log Likelihood               14360.589
# Method:                       css-mle   S.D. of innovations              0.012
# Date:                Fri, 05 Mar 2021   AIC                         -28715.177
# Time:                        01:55:17   BIC                         -28695.754
# Sample:                             1   HQIC                        -28708.355
#
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0002      0.000      1.255      0.210      -0.000       0.001
# ar.L1.D.Close    -0.0065      0.014     -0.449      0.653      -0.035       0.022
#                                     Roots
# ...
#                   Real          Imaginary           Modulus         Frequency
# ...

# %%
fitted_m.plot_predict()

# %%
# Forecast : 결과가 fc에 담깁니다. 
fc, se, conf = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과
lower_series = pd.Series(conf[:, 0], index=test_data.index)  # 예측결과의 하한 바운드
upper_series = pd.Series(conf[:, 1], index=test_data.index)  # 예측결과의 상한 바운드

# Plot
plt.figure(figsize=(9,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.10)
plt.legend()
plt.show()

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  63.036538278978526
# MAE:  6.552833757641732
# RMSE:  7.9395552947868895
# MAPE: 4.53%

# %% [markdown]
# ## Alphabet Inc. (GOOG)

# %%
# Data Load
dataset_goog_filepath = os.getenv('HOME')+'/aiffel/stock_prediction/data/GOOG.csv' 
df_goog = pd.read_csv(dataset_goog_filepath, index_col='Date', parse_dates=True)
ts_goog = df_goog['Close']

# Time Series 생성
rcParams['figure.figsize'] = 13, 6
plt.plot(ts_goog)

ts_goog.head()
# Out:
# Date
# 2004-08-19    49.982655
# 2004-08-20    53.952770
# 2004-08-23    54.495735
# 2004-08-24    52.239197
# 2004-08-25    52.802086
# Name: Close, dtype: float64

# %%
# 결측치 처리
ts_goog[ts_goog.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 결측치가 있다면 이를 보간합니다. 보간 기준은 time을 선택합니다. 
ts_goog=ts_goog.interpolate(method='time')

# 보간 이후 결측치(NaN) 유무를 다시 확인합니다.
print(ts_goog[ts_goog.isna()])

plt.plot(ts_goog)
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환
ts_goog_log = np.log(ts_goog)
plt.plot(ts_goog_log)

# %%
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  
    rolstd = timeseries.rolling(window=window).std()

    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

# %%
def augmented_dickey_fuller_test(timeseries):
    dftest = adfuller(timeseries, autolag='AIC')  
    
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_goog_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_goog_log)

#시계열 분해 (Time Series Decomposition)
decomposition_goog = seasonal_decompose(ts_goog_log, model='multiplicative', period = 30) 

trend_goog = decomposition_goog.trend
seasonal_goog = decomposition_goog.seasonal
residual_goog = decomposition_goog.resid

plt.rcParams["figure.figsize"] = (11,6)
plt.subplot(411)
plt.plot(ts_goog_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend_goog, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal_goog,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual_goog, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -1.872563
# p-value                           0.345077
# #Lags Used                        7.000000
# Number of Observations Used    4156.000000
# Critical Value (1%)              -3.431924
# Critical Value (5%)              -2.862236
# Critical Value (10%)             -2.567140
# dtype: float64

# %%
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.666312e+01
# p-value                        1.567923e-29
# #Lags Used                     3.000000e+01
# Number of Observations Used    4.218000e+03
# Critical Value (1%)           -3.431901e+00
# Critical Value (5%)           -2.862225e+00
# Critical Value (10%)          -2.567135e+00
# dtype: float64

# %%
train_data, test_data = ts_goog_log[:int(len(ts_goog_log)*0.9)], ts_goog_log[int(len(ts_goog_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_goog_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_goog_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
print(ts_goog_log[:2])
print(train_data.shape)
print(test_data.shape)
# Out:
# Date
# 2004-08-19    3.911676
# 2004-08-20    3.988109
# Name: Close, dtype: float64
# (3747,)
# (417,)

# %%
# ACF, PACF 그려보기 -> p,q 구하기
plot_acf(ts_goog_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_goog_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# %%
# 차분 안정성 확인 -> d 구하기
# 1차 차분 구하기
diff_1 = ts_goog_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -24.628386
# p-value                           0.000000
# #Lags Used                        6.000000
# Number of Observations Used    4156.000000
# Critical Value (1%)              -3.431924
# Critical Value (5%)              -2.862236
# Critical Value (10%)             -2.567140
# dtype: float64

# %%
# Build and Train  Model
model = ARIMA(train_data, order=(1, 1, 0))  
fitted_m = model.fit(disp=-1)  
print(fitted_m.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Close   No. Observations:                 3746
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                9554.331
# Method:                       css-mle   S.D. of innovations              0.019
# Date:                Fri, 05 Mar 2021   AIC                         -19102.661
# Time:                        01:55:20   BIC                         -19083.976
# Sample:                             1   HQIC                        -19096.016
#
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0008      0.000      2.666      0.008       0.000       0.001
# ar.L1.D.Close     0.0106      0.016      0.651      0.515      -0.021       0.043
#                                     Roots
# ...
#                   Real          Imaginary           Modulus         Frequency
# ...

# %%
fitted_m.plot_predict()

# %%
# Forecast : 결과가 fc에 담깁니다. 
fc, se, conf = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과
lower_series = pd.Series(conf[:, 0], index=test_data.index)  # 예측결과의 하한 바운드
upper_series = pd.Series(conf[:, 1], index=test_data.index)  # 예측결과의 상한 바운드

# Plot
plt.figure(figsize=(9,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.10)
plt.legend()
plt.show()

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  32929.55087462333
# MAE:  136.58034344256754
# RMSE:  181.46501281134977
# MAPE: 8.64%

# %% [markdown]
# ## 루브릭 평가

# %% [markdown]
# 1. 시계열의 안정성이 충분히 확인되었는가?(플로팅과 adfuller 메소드가 모두 적절히 사용되었음)
#
# 2. ARIMA 모델 모수선택 근거를 체계적으로 제시하였는가?(p,q를 위한 ACF, PACF 사용과 d를 위한 차분 과정이 명확히 제시됨)
#
# 3. 예측 모델의 오차율이 기준 이하로 정확하게 나왔는가?(3개 이상 종목이 MAPE 10% 미만의 정확도로 예측됨)
#
# - 삼성 12.51%, 존슨앤존슨 4.53%, 구글 8.64%의 결과를 얻었습니다.

# %% [markdown]
# ## 회고

# %% [markdown]
# - 시계열 데이터가 Trend와 Seasonality와 Residual로 Decompose됨을 알 수 있었습니다. 시계열 데이터 예측을 ARIMA 모델을 통해 통합적으로 예측을 할 수 있었습니다.
# - 예측이 잘 된 데이터는 통계적으로 안정적인 데이터임을 알 수 있었습니다.
# - ARIMA 모델에서 p, q, d의 모수를 결정하기 위해서 ACF, PACF를 이용하였는데 안정적인 시계열 데이터는 p, q, d 모수가 동일하게 결정이 됩니다.
# - 시장은 코로나와 같이 아무도 예상할 수 없는 상황이 많기에 불규칙적인 주가 변동이 존재하는데 완벽한 주식 예측에 한계를 느낀 프로젝트가 되었습니다.
