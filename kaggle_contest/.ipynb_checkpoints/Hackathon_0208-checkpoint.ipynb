# %% [markdown]
# # ✓ 필요한 라이브러리 import 하기

# %%
import warnings
warnings.filterwarnings("ignore")

import os
from os.path import join

import pandas as pd
import numpy as np

import missingno as msno

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import KFold, cross_val_score
import xgboost as xgb
import lightgbm as lgb

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns


print('얍💢')


# %matplotlib inline
# Out:
# 얍💢

# %% [markdown]
# # ✓ 데이터 경로 지정하기

# %%
# data_dir = os.getenv('HOME')+'/aiffel/kaggle/Hackathon_0208/data'
data_dir = os.getenv('HOME')+'/aiffel/workplace/kaggle_contest/Hackathon_0208/data'

train_data_path = join(data_dir, 'sales_train.csv')
test_data_path = join(data_dir, 'test.csv')      # 테스트, 즉 submission 시 사용할 데이터 경로
item_category_path = join(data_dir,'item_categories.csv')
items_data_path = join(data_dir,'items.csv')
shops_data_path = join(data_dir,'shops.csv')
test_data_path = join(data_dir,'test.csv')
sub_data_path = join(data_dir,'sample_submission.csv')

print(train_data_path)
print(test_data_path)
print(item_category_path)
print(items_data_path)
print(shops_data_path)
print(sub_data_path)
# Out:
# /home/aiffel-dj60/aiffel/kaggle/Hackathon_0208/data/sales_train.csv
# /home/aiffel-dj60/aiffel/kaggle/Hackathon_0208/data/test.csv
# /home/aiffel-dj60/aiffel/kaggle/Hackathon_0208/data/item_categories.csv
# /home/aiffel-dj60/aiffel/kaggle/Hackathon_0208/data/items.csv
# /home/aiffel-dj60/aiffel/kaggle/Hackathon_0208/data/shops.csv
# /home/aiffel-dj60/aiffel/kaggle/Hackathon_0208/data/sample_submission.csv

# %% [markdown]
# # 1. 데이터 살펴보기
# # ✓ 데이터 불러오기

# %%
data = pd.read_csv(train_data_path)
test = pd.read_csv(test_data_path)
item_category= pd.read_csv(item_category_path)
items = pd.read_csv(items_data_path)
shops =pd.read_csv(shops_data_path)
sub = pd.read_csv(sub_data_path)


print('train data dim : {}'.format(data.shape))
print('test data dim : {}'.format(test.shape))
print('item category data dim : {}'.format(item_category.shape))
print('items data dim : {}'.format(items.shape))
print('shops data dim : {}'.format(shops.shape))
print('sub data dim : {}'.format(sub.shape))
# Out:
# train data dim : (2935849, 6)
# test data dim : (214200, 3)
# item category data dim : (84, 2)
# items data dim : (22170, 3)
# shops data dim : (60, 2)
# sub data dim : (214200, 2)

# %%
data.head(3)
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  03.01.2013               0       25     2552       899.0           1.0
# 2  05.01.2013               0       25     2552       899.0          -1.0

# %%
data.tail(3)
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2935846  14.10.2015              33       25     7459       349.0
# 2935847  22.10.2015              33       25     7440       299.0
# 2935848  03.10.2015              33       25     7460       299.0
#
#          item_cnt_day
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0

# %%
test.head(5)
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
item_category.head(5)
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
items.head(5)
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
shops.head(5)
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
sub.head(5)
# Out:
#    ID  item_cnt_month
# 0   0             0.5
# 1   1             0.5
# 2   2             0.5
# 3   3             0.5
# 4   4             0.5

# %%
print("train data 중복 수:",sum(data.duplicated()))

print("test  data 중복 수:",sum(test.duplicated()))
# Out:
# train data 중복 수: 6
# test  data 중복 수: 0

# %% [markdown]
# ### 중복 행 출력

# %%
data[data.duplicated() == True]
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 76962    05.01.2013               0       54    20130       149.0
# 1435367  23.02.2014              13       50     3423       999.0
# 1496766  23.03.2014              14       21     3423       999.0
# 1671873  01.05.2014              16       50     3423       999.0
# 1866340  12.07.2014              18       25     3423       999.0
# 2198566  31.12.2014              23       42    21619       499.0
#
#          item_cnt_day
# 76962             1.0
# 1435367           1.0
# 1496766           1.0
# 1671873           1.0
# 1866340           1.0
# 2198566           1.0

# %% [markdown]
# ### 중복 행 제거

# %%
# 중복 제거
data.drop_duplicates(inplace=True)

# %%
# 중복 재확인
sum(data.duplicated())
# Out:
# 0

# %% [markdown]
# ### 결측치 확인

# %%
#train데이터 결측치 확인
data.isnull().sum()
# Out:
# date              0
# date_block_num    0
# shop_id           0
# item_id           0
# item_price        0
# item_cnt_day      0
# dtype: int64

# %%
#test데이터 결측치 확인
test.isnull().sum()
# Out:
# ID         0
# shop_id    0
# item_id    0
# dtype: int64

# %% [markdown]
# ### outlier (극단치) 제거

# %% [markdown]
# ```
# 극단치란
# 통계적 자료 분석의 결과를 왜곡시키거나, 자료 분석의 적절성을 위협하는 변숫값
#
# 1000과 2000이상의 동떨어진 데이터 들이 존재한다.
# 우리는 500이하로 범위로 좁혀주자.
# ```

# %%
plt.figure(figsize=(10,3))
sns.boxplot(x='item_cnt_day', data=data);

# %%
#outlier (극단치) 제거
data = data[data.item_cnt_day < 500]

# %%
plt.figure(figsize=(10,3))
sns.boxplot(x='item_cnt_day', data=data);

# %% [markdown]
# ### 음수값도 제거 해주자.

# %%
data = data[data.item_cnt_day >= 0]

# %%
plt.figure(figsize=(10,3))
sns.boxplot(x='item_cnt_day', data=data);

# %%
print('train data dim : {}'.format(data.shape))
# Out:
# train data dim : (2928473, 6)

# %% [markdown]
# 2935849 -> 2928473로 변경

# %% [markdown]
# # Items Analysis
#
# Training Set에는 1804개의  item 존재
# Test Set에는 5100개의  item 존재

# %%
items_train = data['item_id'].nunique()
items_test = test['item_id'].nunique()
print('Items in Training Set: ', items_train)
print('Items in Test Set: ', items_test)
# Out:
# Items in Training Set:  21804
# Items in Test Set:  5100

# %%
group = data.groupby(['date_block_num', 'shop_id', 'item_id']).agg({'item_cnt_day': ['sum']})

group
# Out:
#                                item_cnt_day
#                                         sum
# date_block_num shop_id item_id
# 0              0       32               6.0
#                        33               3.0
#                        35               1.0
#                        43               1.0
#                        51               2.0
# ...                                     ...
# 33             59      22087            6.0
#                        22088            2.0
#                        22091            1.0
#                        22100            1.0
#                        22102            1.0
#
# [1608223 rows x 1 columns]

# %%
.columns = ['item_cnt_month']group

# %%
group
# Out:
#                                 item_cnt_month
# date_block_num shop_id item_id
# 0              0       32                  6.0
#                        33                  3.0
#                        35                  1.0
#                        43                  1.0
#                        51                  2.0
# ...                                        ...
# 33             59      22087               6.0
#                        22088               2.0
#                        22091               1.0
#                        22100               1.0
#                        22102               1.0
#
# [1608223 rows x 1 columns]

# %%
group.reset_index(inplace=True)

# %%
group.head(5)
# Out:
#    date_block_num  shop_id  item_id  item_cnt_month
# 0               0        0       32             6.0
# 1               0        0       33             3.0
# 2               0        0       35             1.0
# 3               0        0       43             1.0
# 4               0        0       51             2.0

# %%
group.tail(5)
# Out:
#          date_block_num  shop_id  item_id  item_cnt_month
# 1608218              33       59    22087             6.0
# 1608219              33       59    22088             2.0
# 1608220              33       59    22091             1.0
# 1608221              33       59    22100             1.0
# 1608222              33       59    22102             1.0

# %%
print(group.shape)
group.head(3)
# Out:
# (1608223, 4)
#    date_block_num  shop_id  item_id  item_cnt_month
# 0               0        0       32             6.0
# 1               0        0       33             3.0
# 2               0        0       35             1.0

# %%
print(test.shape)
test.head(3)
# Out:
# (214200, 5)
#    ID  shop_id  item_id  date_block_num  item_cnt_month
# 0   0        5     5037              34               0
# 1   1        5     5320              34               0
# 2   2        5     5233              34               0

# %% [markdown]
# # 테스트 데이터에 컬럼 추가하기
#
# Appending Test Set to Training Set
# First, let's insert the date_block_num feature for the test set! Using insert method of pandas to place this new column at a specific index. This will allow us to concatenate the test set easily to the training set before we generate mean encodings and lag features

# %%
test['date_block_num'] = 34
test['date_block_num'] = test['date_block_num'].astype(np.int8)
test['shop_id'] = test['shop_id'].astype(np.int8)
test['item_id'] = test['item_id'].astype(np.int16)
test['item_cnt_month'] = 0
test['item_cnt_month'] = test['item_cnt_month'].astype(np.int8)


print(test.shape)
test.head(3)
# Out:
# (214200, 5)
#         shop_id  item_id  date_block_num  item_cnt_month
# 0             5     5037              34               0
# 1             5     5320              34               0
# 2             5     5233              34               0
# 3             5     5232              34               0
# 4             5     5268              34               0
# ...         ...      ...             ...             ...
# 214195       45    18454              34               0
# 214196       45    16188              34               0
# 214197       45    15757              34               0
# 214198       45    19648              34               0
# 214199       45      969              34               0
#
# [214200 rows x 4 columns]

# %% [markdown]
# ### ID 컬럼 삭제

# %%
sub_id =test['ID'][:]
sub=  test.drop('ID', axis = 1)
sub
# Out:
#         shop_id  item_id  date_block_num  item_cnt_month
# 0             5     5037              34               0
# 1             5     5320              34               0
# 2             5     5233              34               0
# 3             5     5232              34               0
# 4             5     5268              34               0
# ...         ...      ...             ...             ...
# 214195       45    18454              34               0
# 214196       45    16188              34               0
# 214197       45    15757              34               0
# 214198       45    19648              34               0
# 214199       45      969              34               0
#
# [214200 rows x 4 columns]

# %%
new_train = group.append(test.drop('ID', axis = 1))

# %%
new_train
# Out:
#         date_block_num  shop_id  item_id  item_cnt_month
# 0                    0        0       32             6.0
# 1                    0        0       33             3.0
# 2                    0        0       35             1.0
# 3                    0        0       43             1.0
# 4                    0        0       51             2.0
# ...                ...      ...      ...             ...
# 214195              34       45    18454             0.0
# 214196              34       45    16188             0.0
# 214197              34       45    15757             0.0
# 214198              34       45    19648             0.0
# 214199              34       45      969             0.0
#
# [1822423 rows x 4 columns]

# %%
import xgboost as xgb

# %%
new_train = new_train[new_train.date_block_num > 11]

new_train
# Out:
#         date_block_num  shop_id  item_id  item_cnt_month
# 687353              12        2       32             1.0
# 687354              12        2       33             1.0
# 687355              12        2       99             1.0
# 687356              12        2      482             2.0
# 687357              12        2      485             1.0
# ...                ...      ...      ...             ...
# 214195              34       45    18454             0.0
# 214196              34       45    16188             0.0
# 214197              34       45    15757             0.0
# 214198              34       45    19648             0.0
# 214199              34       45      969             0.0
#
# [1135070 rows x 4 columns]

# %%
new_train_g = group[group.date_block_num > 30]
new_train_g
# Out:
#          date_block_num  shop_id  item_id  item_cnt_month
# 1513579              31        2       32             1.0
# 1513580              31        2       70             1.0
# 1513581              31        2      482             1.0
# 1513582              31        2      792             2.0
# 1513583              31        2      806             1.0
# ...                 ...      ...      ...             ...
# 1608218              33       59    22087             6.0
# 1608219              33       59    22088             2.0
# 1608220              33       59    22091             1.0
# 1608221              33       59    22100             1.0
# 1608222              33       59    22102             1.0
#
# [94644 rows x 4 columns]

# %% [markdown]
# # 로그화시킴

# %%
new_train_g['item_cnt_month'] = np.log1p(new_train_g['item_cnt_month'].values)

# %%
gboost = GradientBoostingRegressor(random_state=2019)
xgboost = xgb.XGBRegressor(random_state=2019)
lightgbm = lgb.LGBMRegressor(random_state=2019)

models = [{'model':gboost, 'name':'GradientBoosting'}, {'model':xgboost, 'name':'XGBoost'},
          {'model':lightgbm, 'name':'LightGBM'}]

print('얍💢')
# Out:
# 얍💢

# %% [markdown]
# https://homeproject.tistory.com/entry/%EA%B5%90%EC%B0%A8%EA%B2%80%EC%A6%9D-cross-validation

# %%
def get_cv_score(models):
    kfold = KFold(n_splits=5, random_state=2019).get_n_splits(new_train_g.values)
    for m in models:
        print("Model {} CV score : {:.4f}".format(m['name'], np.mean(cross_val_score(m['model'], new_train_g.values, new_train_g['item_cnt_month'])), 
                                                  cv=kfold))
print('얍💢')
# Out:
# 얍💢

# %%
get_cv_score(models)
# Out:
# Model GradientBoosting CV score : 1.0000
# Model XGBoost CV score : 1.0000
# Model LightGBM CV score : 0.9996

# %%
def AveragingBlending(models, x, y, sub_x):
    for m in models : 
        m['model'].fit(x.values, y)
    
    predictions = np.column_stack([
        m['model'].predict(sub_x.values) for m in models
    ])
    return np.mean(predictions, axis=1)

print('얍💢')
# Out:
# 얍💢

# %%
y_pred = AveragingBlending(models, new_train_g, new_train_g['item_cnt_month'], sub)
print(len(y_pred))
y_pred
# Out:
# 214200
# array([0.69316179, 0.69316179, 0.69316179, ..., 0.69316179, 0.69316179,
#        0.69316179])

# %%
result = pd.DataFrame({
    'id' : sub_id, 
    'item_cnt_month' : y_pred
})

result
# Out:
#             id  item_cnt_month
# 0            0        0.693162
# 1            1        0.693162
# 2            2        0.693162
# 3            3        0.693162
# 4            4        0.693162
# ...        ...             ...
# 214195  214195        0.693162
# 214196  214196        0.693162
# 214197  214197        0.693162
# 214198  214198        0.693162
# 214199  214199        0.693162
#
# [214200 rows x 2 columns]

# %%
(21312312,23 )

(123,)
